# %% [markdown]
# # 1. 讀入資料

# %%
import pandas as pd
df = pd.read_csv("2012-18_NBA_officialBoxScore.csv")
df
# Out:
#            gmDate gmTime     offLNm offFNm teamAbbr teamConf    teamDiv  \
# 0      2012/10/30  19:00   Brothers   Tony      WAS     East  Southeast
# 1      2012/10/30  19:00   Brothers   Tony      CLE     East    Central
# 2      2012/10/30  20:00  McCutchen  Monty      BOS     East   Atlantic
# 3      2012/10/30  20:00  McCutchen  Monty      MIA     East  Southeast
# 4      2012/10/30  22:30     Foster  Scott      DAL     West  Southwest
# ...           ...    ...        ...    ...      ...      ...        ...
# 14753   2018/4/11  10:30  Garretson    Ron      LAC     West    Pacific
# 14754   2018/4/11  10:30     Cutler  Kevin      UTA     West  Northwest
# 14755   2018/4/11  10:30     Cutler  Kevin      POR     West  Northwest
# 14756   2018/4/11  10:30      Tiven   Josh      HOU     West  Southwest
# 14757   2018/4/11  10:30      Tiven   Josh      SAC     West    Pacific
#
#       teamLoc teamRslt  teamMin  ...  opptFIC40  opptOrtg  opptDrtg  \
# 0        Away     Loss      240  ...    61.6667  105.6882   94.4447
# 1        Home      Win      240  ...    56.0417   94.4447  105.6882
# 2        Away     Loss      240  ...    80.8333  126.3381  112.6515
# 3        Home      Win      240  ...    62.7083  112.6515  126.3381
# 4        Away      Win      240  ...    58.6458   99.3678  108.1034
# ...       ...      ...      ...  ...        ...       ...       ...
# 14753    Home     Loss      240  ...    77.2917  113.0207   98.2788
# 14754    Away     Loss      241  ...    67.9167  104.4268   95.2126
# 14755    Home      Win      240  ...    54.7718   95.2126  104.4268
# 14756    Away     Loss      241  ...    65.8333  104.3633   90.2307
# 14757    Home      Win      240  ...    34.8548   90.2307  104.3633
#
#        opptEDiff  opptPlay%   opptAR  opptAST/TO  opptSTL/TO      poss  \
# 0        11.2435     0.4390  16.7072      1.0476     33.3333   88.9409
# 1       -11.2435     0.3765  18.8679      2.0000     84.6154   88.9409
# 2        13.6866     0.5244  19.8287      3.1250    100.0000   94.9832
# 3       -13.6866     0.4643  18.8501      1.5000     25.0000   94.9832
# 4        -8.7356     0.5000  18.6567      1.7143     42.8571   91.5790
# ...          ...        ...      ...         ...         ...       ...
# 14753    14.7419     0.4421  18.2428      1.4706     47.0588  101.7513
# 14754     9.2142     0.4457  15.1951      1.9000     90.0000   97.6761
# 14755    -9.2142     0.3667  13.5788      1.2000     33.3333   97.6761
# 14756    14.1326     0.4471  18.0624      2.0000     54.5455   91.9864
# 14757   -14.1326     0.3523   9.7969      0.7857     14.2857   91.9864
#
#            pace
# 0       88.9409
# 1       88.9409
# 2       94.9832
# 3       94.9832
# 4       91.5790
# ...         ...
# 14753  101.7513
# 14754   97.2708
# 14755   97.6761
# 14756   91.6047
# 14757   91.9864
#
# [14758 rows x 119 columns]

# %% [markdown]
# # 2. 檢查資料缺失值
# ## 共有119欄、沒有欄位存在缺失值

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14758 entries, 0 to 14757
# Columns: 119 entries, gmDate to pace
# dtypes: float64(51), int64(54), object(14)
# memory usage: 13.4+ MB

# %%
num = df.isna().sum()
num
# Out:
# gmDate        0
# gmTime        0
# offLNm        0
# offFNm        0
# teamAbbr      0
#              ..
# opptAR        0
# opptAST/TO    0
# opptSTL/TO    0
# poss          0
# pace          0
# Length: 119, dtype: int64

# %%
count = 0
for i in num:
    if i == 0:
        count+=1
count
# Out:
# 119

# %%
df
# Out:
#            gmDate gmTime     offLNm offFNm teamAbbr teamConf    teamDiv  \
# 0      2012/10/30  19:00   Brothers   Tony      WAS     East  Southeast
# 1      2012/10/30  19:00   Brothers   Tony      CLE     East    Central
# 2      2012/10/30  20:00  McCutchen  Monty      BOS     East   Atlantic
# 3      2012/10/30  20:00  McCutchen  Monty      MIA     East  Southeast
# 4      2012/10/30  22:30     Foster  Scott      DAL     West  Southwest
# ...           ...    ...        ...    ...      ...      ...        ...
# 14753   2018/4/11  10:30  Garretson    Ron      LAC     West    Pacific
# 14754   2018/4/11  10:30     Cutler  Kevin      UTA     West  Northwest
# 14755   2018/4/11  10:30     Cutler  Kevin      POR     West  Northwest
# 14756   2018/4/11  10:30      Tiven   Josh      HOU     West  Southwest
# 14757   2018/4/11  10:30      Tiven   Josh      SAC     West    Pacific
#
#       teamLoc teamRslt  teamMin  ...  opptFIC40  opptOrtg  opptDrtg  \
# 0        Away     Loss      240  ...    61.6667  105.6882   94.4447
# 1        Home      Win      240  ...    56.0417   94.4447  105.6882
# 2        Away     Loss      240  ...    80.8333  126.3381  112.6515
# 3        Home      Win      240  ...    62.7083  112.6515  126.3381
# 4        Away      Win      240  ...    58.6458   99.3678  108.1034
# ...       ...      ...      ...  ...        ...       ...       ...
# 14753    Home     Loss      240  ...    77.2917  113.0207   98.2788
# 14754    Away     Loss      241  ...    67.9167  104.4268   95.2126
# 14755    Home      Win      240  ...    54.7718   95.2126  104.4268
# 14756    Away     Loss      241  ...    65.8333  104.3633   90.2307
# 14757    Home      Win      240  ...    34.8548   90.2307  104.3633
#
#        opptEDiff  opptPlay%   opptAR  opptAST/TO  opptSTL/TO      poss  \
# 0        11.2435     0.4390  16.7072      1.0476     33.3333   88.9409
# 1       -11.2435     0.3765  18.8679      2.0000     84.6154   88.9409
# 2        13.6866     0.5244  19.8287      3.1250    100.0000   94.9832
# 3       -13.6866     0.4643  18.8501      1.5000     25.0000   94.9832
# 4        -8.7356     0.5000  18.6567      1.7143     42.8571   91.5790
# ...          ...        ...      ...         ...         ...       ...
# 14753    14.7419     0.4421  18.2428      1.4706     47.0588  101.7513
# 14754     9.2142     0.4457  15.1951      1.9000     90.0000   97.6761
# 14755    -9.2142     0.3667  13.5788      1.2000     33.3333   97.6761
# 14756    14.1326     0.4471  18.0624      2.0000     54.5455   91.9864
# 14757   -14.1326     0.3523   9.7969      0.7857     14.2857   91.9864
#
#            pace
# 0       88.9409
# 1       88.9409
# 2       94.9832
# 3       94.9832
# 4       91.5790
# ...         ...
# 14753  101.7513
# 14754   97.2708
# 14755   97.6761
# 14756   91.6047
# 14757   91.9864
#
# [14758 rows x 119 columns]

# %% [markdown]
# # 3. 在主場打比較容易贏?
# ## 根據統計數據，可以發現在主場打贏的場次確實比較多

# %%
df_stat = df[["teamAbbr","teamLoc","teamRslt"]]
df_stat.groupby(["teamLoc","teamRslt"]).size()
# Out:
# teamLoc  teamRslt
# Away     Loss        4327
#          Win         3052
# Home     Loss        3052
#          Win         4327
# dtype: int64

# %% [markdown]
# ## 3.1 以湖人隊為例
# ### 在主場的勝場數確實也大於客場 主:107 (42.2764%) 客:67 (27.2358%)

# %%
df_LAL = df[df["teamAbbr"]=="LAL"]
df_LAL
# Out:
#            gmDate gmTime     offLNm  offFNm teamAbbr teamConf  teamDiv  \
# 5      2012/10/30  22:30     Foster   Scott      LAL     West  Pacific
# 22     2012/10/31  22:30       Wood    Leon      LAL     West  Pacific
# 47      2012/11/2  22:30      Adams  Bennie      LAL     West  Pacific
# 79      2012/11/4  21:30      Mauer     Ken      LAL     West  Pacific
# 120     2012/11/7  21:00     Malloy      Ed      LAL     West  Pacific
# ...           ...    ...        ...     ...      ...      ...      ...
# 14645    2018/4/4  10:30      Tiven    Josh      LAL     West  Pacific
# 14677    2018/4/6  10:30        Orr    J.T.      LAL     West  Pacific
# 14697    2018/4/8  06:00     Foster   Scott      LAL     West  Pacific
# 14733   2018/4/10  10:30  Twardoski   Scott      LAL     West  Pacific
# 14752   2018/4/11  10:30  Garretson     Ron      LAL     West  Pacific
#
#       teamLoc teamRslt  teamMin  ...  opptFIC40  opptOrtg  opptDrtg  \
# 5        Home     Loss      240  ...    60.2083  108.1034   99.3678
# 22       Away     Loss      240  ...    66.8750  123.0620  112.4532
# 47       Home     Loss      240  ...    64.0625  111.9107  101.2525
# 79       Home      Win      240  ...    34.2708   91.0612  124.4888
# 120      Away     Loss      240  ...    57.5000  102.8336   93.0914
# ...       ...      ...      ...  ...        ...       ...       ...
# 14645    Home      Win      266  ...    63.9205  109.7062  119.5013
# 14677    Home     Loss      240  ...    82.6360  116.6460   99.0975
# 14697    Home     Loss      240  ...    78.6611  110.1578   95.4045
# 14733    Home     Loss      240  ...    63.8075  101.5008   95.7007
# 14752    Away      Win      240  ...    58.7500   98.2788  113.0207
#
#        opptEDiff  opptPlay%   opptAR  opptAST/TO  opptSTL/TO      poss  \
# 5         8.7356     0.4545  17.3338      1.8333     75.0000   91.5790
# 22       10.6088     0.4941  15.0412      1.5833     83.3333   94.2614
# 47       10.6582     0.4368  18.1984      2.0000    100.0000   93.8248
# 79      -33.4276     0.3373  15.1854      1.1176     29.4118   86.7548
# 120       9.7422     0.4302  16.9464      1.7500    100.0000   92.3823
# ...          ...        ...      ...         ...         ...       ...
# 14645    -9.7951     0.4565  17.3756      2.5000     70.0000  102.0909
# 14677    17.5485     0.4943  17.6753      5.0000    280.0000   96.8743
# 14697    14.7533     0.4468  24.0253      1.9444     44.4444  101.6723
# 14733     5.8001     0.3737  14.2814      1.0000     47.3684  103.4475
# 14752   -14.7419     0.4457  19.3798      1.5882     47.0588  101.7513
#
#            pace
# 5       91.5790
# 22      94.2614
# 47      93.8248
# 79      86.7548
# 120     92.3823
# ...         ...
# 14645   92.1121
# 14677   96.8743
# 14697  101.6723
# 14733  103.4475
# 14752  101.7513
#
# [492 rows x 119 columns]

# %% [markdown]
# ## 3.2 詳細的主客場勝負場數 (湖人隊)

# %%
print(df_LAL.groupby(["teamLoc","teamRslt"]).size())
section = df_LAL.groupby(["teamLoc"])
# Out:
# teamLoc  teamRslt
# Away     Loss        179
#          Win          67
# Home     Loss        142
#          Win         104
# dtype: int64

# %% [markdown]
# ## 3.3 主客場勝率 (湖人隊)

# %%
Away = pd.DataFrame(section.get_group("Away")["teamRslt"])
Home = pd.DataFrame(section.get_group("Home")["teamRslt"])
def countWinRate(teamLoc):
    Loss = len(teamLoc[teamLoc["teamRslt"] == "Loss"])
    Win = len(teamLoc[teamLoc["teamRslt"] == "Win"])  
    df = pd.DataFrame({"Win":Win,"Loss":Loss,"Win Rate":(Win/(Loss+Win))},index=[0])

    return df

print("Win Rate at Away")
print(countWinRate(Away))
print('='*25)
print("Win Rate at Home")
print(countWinRate(Home))
# Out:
# Win Rate at Away
#    Win  Loss  Win Rate
# 0   67   179  0.272358
# =========================
# Win Rate at Home
#    Win  Loss  Win Rate
# 0  104   142  0.422764

# %% [markdown]
# ## 3.4 總勝敗場數 (湖人隊)

# %%
# 湖人隊的勝敗數
df_LAL.groupby(["teamRslt"]).size()
# Out:
# teamRslt
# Loss    321
# Win     171
# dtype: int64

# %% [markdown]
# # 4. 利用主成分分析(PCA)，挑出前20個屬性恰可獲得對99%變異數貢獻最大的特徵
#
# 主成分分析經常用於減少數據集的維數，同時保留數據集當中對變異數貢獻最大的特徵。這是通過保留低維主成分，忽略高維主成分做到的。這樣低維成分往往能夠保留住數據的最重要部分。但是，這也不是一定的，要視具體應用而定。由於主成分分析依賴所給數據，所以數據的準確性對分析結果影響很大。

# %%
from sklearn.decomposition import PCA
import numpy as np

dx = df.drop(['gmDate','gmTime','offLNm','offFNm','teamAbbr','teamConf','teamDiv','opptConf','opptDiv','opptLoc',
                'opptRslt','teamRslt','opptAbbr','teamPTS1','teamPTS2','teamPTS3','teamPTS4','teamPTS5','teamPTS6','teamPTS7','teamPTS8',
                'opptPTS1','opptPTS2','opptPTS3','opptPTS4','opptPTS5','opptPTS6','opptPTS7','opptPTS8'],axis=1)

def changeTeamLoc(df):
    if df == 'Home':
        return 0
    if df == 'Away':
        return 1
dxx = dx
dx['teamLoc'] = dx['teamLoc'].apply(changeTeamLoc)
dn = dx.to_numpy()
# 取出特徵名稱
features_names = dx.columns
pca = PCA().fit(dn)
# 依變異解釋能力找出對應特徵
indexes = np.argmax(np.abs(pca.components_), axis=1)
var_ratio = pca.explained_variance_ratio_ * 100
for i, idx in enumerate(indexes):
    print(f'PC{i+1} ({var_ratio[i]:.5f} %) ' + \
          f'feature {idx} ({features_names[idx]})')
# Out:
# PC1 (29.34655 %) feature 87 (opptSTL/TO)
# PC2 (18.87801 %) feature 87 (opptSTL/TO)
# PC3 (15.38807 %) feature 79 (opptFIC)
# PC4 (6.33129 %) feature 87 (opptSTL/TO)
# PC5 (4.65436 %) feature 9 (teamFGA)
# PC6 (4.38541 %) feature 56 (oppt2PA)
# PC7 (3.49352 %) feature 26 (teamASST%)
# PC8 (2.88896 %) feature 12 (team2PA)
# PC9 (2.16695 %) feature 69 (opptASST%)
# PC10 (2.02483 %) feature 62 (opptFTA)
# PC11 (1.79204 %) feature 59 (oppt3PA)
# PC12 (1.63972 %) feature 1 (teamMin)
# PC13 (1.51386 %) feature 29 (teamOREB%)
# PC14 (1.36364 %) feature 15 (team3PA)
# PC15 (1.12169 %) feature 5 (teamTO)
# PC16 (0.75032 %) feature 77 (opptBLKR)
# PC17 (0.59139 %) feature 34 (teamBLKR)
# PC18 (0.42895 %) feature 23 (teamDRB)
# PC19 (0.22890 %) feature 52 (opptPF)
# PC20 (0.16107 %) feature 13 (team2PM)
# PC21 (0.14642 %) feature 57 (oppt2PM)
# PC22 (0.11663 %) feature 52 (opptPF)
# PC23 (0.11497 %) feature 8 (teamPF)
# PC24 (0.09369 %) feature 53 (opptFGA)
# PC25 (0.06289 %) feature 32 (teamSTL%)
# PC26 (0.05658 %) feature 19 (teamFTA)
# PC27 (0.05039 %) feature 49 (opptTO)
# PC28 (0.04458 %) feature 62 (opptFTA)
# PC29 (0.04163 %) feature 32 (teamSTL%)
# PC30 (0.02962 %) feature 2 (teamDayOff)
# PC31 (0.01423 %) feature 30 (teamDREB%)
# PC32 (0.01180 %) feature 46 (opptDayOff)
# PC33 (0.00908 %) feature 65 (opptORB)
# PC34 (0.00822 %) feature 30 (teamDREB%)
# PC35 (0.00709 %) feature 22 (teamORB)
# PC36 (0.00643 %) feature 65 (opptORB)
# PC37 (0.00592 %) feature 45 (opptMin)
# PC38 (0.00443 %) feature 25 (teamTREB%)
# PC39 (0.00408 %) feature 4 (teamAST)
# PC40 (0.00396 %) feature 34 (teamBLKR)
# PC41 (0.00392 %) feature 0 (teamLoc)
# PC42 (0.00378 %) feature 77 (opptBLKR)
# PC43 (0.00324 %) feature 4 (teamAST)
# PC44 (0.00131 %) feature 80 (opptFIC40)
# PC45 (0.00103 %) feature 86 (opptAST/TO)
# PC46 (0.00067 %) feature 86 (opptAST/TO)
# PC47 (0.00061 %) feature 74 (opptTO%)
# PC48 (0.00053 %) feature 86 (opptAST/TO)
# PC49 (0.00047 %) feature 42 (teamAR)
# PC50 (0.00043 %) feature 37 (teamFIC40)
# PC51 (0.00041 %) feature 42 (teamAR)
# PC52 (0.00038 %) feature 89 (pace)
# PC53 (0.00023 %) feature 33 (teamBLK%)
# PC54 (0.00021 %) feature 76 (opptBLK%)
# PC55 (0.00016 %) feature 75 (opptSTL%)
# PC56 (0.00014 %) feature 32 (teamSTL%)
# PC57 (0.00013 %) feature 88 (poss)
# PC58 (0.00008 %) feature 18 (3/2+3)
# PC59 (0.00002 %) feature 21 (teamFT%)
# PC60 (0.00002 %) feature 64 (opptFT%)
# PC61 (0.00002 %) feature 61 (oppt3P%)
# PC62 (0.00002 %) feature 17 (team3P%)
# PC63 (0.00000 %) feature 78 (opptPPS)
# PC64 (0.00000 %) feature 35 (teamPPS)
# PC65 (0.00000 %) feature 58 (oppt2P%)
# PC66 (0.00000 %) feature 14 (team2P%)
# PC67 (0.00000 %) feature 54 (opptFGM)
# PC68 (0.00000 %) feature 10 (teamFGM)
# PC69 (0.00000 %) feature 71 (opptEFG%)
# PC70 (0.00000 %) feature 28 (teamEFG%)
# PC71 (0.00000 %) feature 70 (opptTS%)
# PC72 (0.00000 %) feature 27 (teamTS%)
# PC73 (0.00000 %) feature 71 (opptEFG%)
# PC74 (0.00000 %) feature 28 (teamEFG%)
# PC75 (0.00000 %) feature 11 (teamFG%)
# PC76 (0.00000 %) feature 41 (teamPlay%)
# PC77 (0.00000 %) feature 83 (opptEDiff)
# PC78 (0.00000 %) feature 73 (opptDREB%)
# PC79 (0.00000 %) feature 83 (opptEDiff)
# PC80 (0.00000 %) feature 73 (opptDREB%)
# PC81 (0.00000 %) feature 9 (teamFGA)
# PC82 (0.00000 %) feature 53 (opptFGA)
# PC83 (0.00000 %) feature 38 (teamOrtg)
# PC84 (0.00000 %) feature 38 (teamOrtg)
# PC85 (0.00000 %) feature 39 (teamDrtg)
# PC86 (0.00000 %) feature 25 (teamTREB%)
# PC87 (0.00000 %) feature 81 (opptOrtg)
# PC88 (0.00000 %) feature 68 (opptTREB%)
# PC89 (0.00000 %) feature 65 (opptORB)
# PC90 (0.00000 %) feature 40 (teamEDiff)

# %%
count = 0
for i in range(20):
    count += var_ratio[i]

print(count)
# Out:
# 99.14952265189304

# %% [markdown]
# # 5. 利用 LogisticRegression 預測比賽的勝利與否 (放入PCA找出的欄位做預測)

# %% [markdown]
# ## 5.1 模型預測 (Accuracy、Recall、Precision、F1 score)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix
import numpy as np

def changeTeamRslt(teamRslt):
    if teamRslt == "Win":
        return 1
    if teamRslt == "Loss":
        return 0

dy = df["teamRslt"].apply(changeTeamRslt)
dx = PCA(n_components=20).fit_transform(dx)
dx = StandardScaler().fit_transform(dx)
dx_train, dx_test, dy_train, dy_test = \
          train_test_split(dx, dy, test_size=0.2, random_state=0)
model = LogisticRegression()
model.fit(dx_train, dy_train)
predict = model.predict(dx_test)
accuracy = accuracy_score(dy_test, predict)
precision = precision_score(dy_test, predict,pos_label=1)
recall = recall_score(dy_test, predict,pos_label=1)
f1_score = f1_score(dy_test, predict,pos_label=1)
summary = pd.DataFrame({'Accuracy':accuracy,'Precision':precision,'Recall':recall,'f1_score':f1_score},index=['LogisticRegression']) 
summary
# Out:
#                     Accuracy  Precision    Recall  f1_score
# LogisticRegression  0.999322   0.999325  0.999325  0.999325

# %% [markdown]
# ## 5.2 Confusion Matrix 混淆矩陣 (Logistic Regression)

# %%
confusion_matrix(dy_test,predict)
# Out:
# array([[1469,    1],
#        [   1, 1481]], dtype=int64)

# %% [markdown]
# ## 5.3 預測結果的 ROC Curve (Logistic Regression)
# ### 預測準確率過高可能是Overfitting導致

# %%
from sklearn.metrics import roc_curve

def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('NBA Game Prediction ROC Curve')
    plt.legend()
    plt.show()
    

fper, tper, thresholds = roc_curve(dy_test,predict)
plot_roc_curve(fper, tper)

# %% [markdown]
# # 6. 利用 SVM 預測比賽的勝利與否 (放入PCA找出的欄位做預測)

# %% [markdown]
# ## 6.1 Confusion Matrix 混淆矩陣、預測結果報告 (SVM)

# %%
#dx_train, dx_test, dy_train, dy_tes
#載入Support Vector Classifier套件
from sklearn.svm import SVC
model = SVC(kernel='sigmoid',C=1,gamma='auto')
#使用Support Vector Classifier來建立模型
model.fit(dx_train,dy_train)
#利用測試組資料來測試模型結果
predictions = model.predict(dx_test)
#載入classification report & confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(dy_test,predictions))
print('\n')
print(classification_report(dy_test,predictions))
# Out:
# [[1423   47]
#  [  47 1435]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      1470
#            1       0.97      0.97      0.97      1482
#
#     accuracy                           0.97      2952
#    macro avg       0.97      0.97      0.97      2952
# weighted avg       0.97      0.97      0.97      2952

# %% [markdown]
# ## 6.2 ROC Curve (SVM)

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot as plt
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('NBA Game Prediction ROC Curve')
    plt.legend()
    plt.show()
    

fper, tper, thresholds = roc_curve(dy_test,predictions)
plot_roc_curve(fper, tper)

# %% [markdown]
# # 7. 利用 Decision Tree 預測比賽的勝利與否 (放入PCA找出的欄位做預測)

# %% [markdown]
# ## 7.1 預測結果報告

# %%
#dx_train, dx_test, dy_train, dy_tes
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=4)
clf = clf.fit(dx_train, dy_train)
predict = clf.predict(dx_test)
print(classification_report(dy_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1470
#            1       0.94      0.95      0.95      1482
#
#     accuracy                           0.94      2952
#    macro avg       0.94      0.94      0.94      2952
# weighted avg       0.94      0.94      0.94      2952

# %% [markdown]
# ## 7.2 ROC Curve

# %%
from sklearn.metrics import roc_curve
from matplotlib import pyplot as plt
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='green', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('NBA Win Game Prediction ROC Curve')
    plt.legend()
    plt.show()
    

fper, tper, thresholds = roc_curve(dy_test,predict)
plot_roc_curve(fper, tper)

# %% [markdown]
# ## 7.3 將決策樹視覺化後存成圖檔

# %%
plt.figure(figsize=(25, 20),dpi=200)
tree.plot_tree(clf,filled=True)  
plt.savefig('tree.png')
